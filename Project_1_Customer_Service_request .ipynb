# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# Project - 1
# Customer Service Requests Analysis.

# %%
df=pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
df.tail()
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 364553  New York City Police Department          Illegal Parking
# 364554  New York City Police Department          Noise - Vehicle
# 364555  New York City Police Department  Noise - Street/Sidewalk
# 364556  New York City Police Department         Blocked Driveway
# 364557  New York City Police Department         Blocked Driveway
#
#               Descriptor    Location Type  Incident Zip      Incident Address  \
# ...

# %%
df.shape #1.Shape of the DATA
# Out:
# (364558, 53)

# %%
df.isna().apply(pd.value_counts).T #2.Variables with Null Values
# Out:
#                                    False      True
# Unique Key                      364558.0       NaN
# Created Date                    364558.0       NaN
# Closed Date                     362177.0    2381.0
# Agency                          364558.0       NaN
# Agency Name                     364558.0       NaN
# Complaint Type                  364558.0       NaN
# Descriptor                      358057.0    6501.0
# Location Type                   364425.0     133.0
# Incident Zip                    361560.0    2998.0
# Incident Address                312859.0   51699.0
# Street Name                     312859.0   51699.0
# Cross Street 1                  307370.0   57188.0
# Cross Street 2                  306753.0   57805.0
# Intersection Street 1            51120.0  313438.0
# Intersection Street 2            50512.0  314046.0
# Address Type                    361306.0    3252.0
# City                            361561.0    2997.0
# ...

# %%
df_1=df.drop(['Ferry Terminal Name','Ferry Direction','Garage Lot Name','Bridge Highway Segment','Road Ramp','Bridge Highway Direction','Bridge Highway Name','Taxi Pick Up Location','Taxi Company Borough','Vehicle Type','School or Citywide Complaint','Landmark'],axis=1,inplace=True)

# %%
a=((df.isna().sum())/len(df))*100 #Percentage of remaining Null Values
a
# Out:
# Unique Key                         0.000000
# Created Date                       0.000000
# Closed Date                        0.653120
# Agency                             0.000000
# Agency Name                        0.000000
# Complaint Type                     0.000000
# Descriptor                         1.783255
# Location Type                      0.036483
# Incident Zip                       0.822366
# Incident Address                  14.181283
# Street Name                       14.181283
# Cross Street 1                    15.686941
# Cross Street 2                    15.856187
# Intersection Street 1             85.977540
# Intersection Street 2             86.144317
# Address Type                       0.892039
# City                               0.822091
# Facility Type                      0.655314
# Status                             0.000000
# Due Date                           0.000823
# Resolution Description             0.000000
# ...

# %%
df_2=df.drop(['Intersection Street 1','Intersection Street 2'],axis=1,inplace=True)

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                                    False     True
# Unique Key                      364558.0      NaN
# Created Date                    364558.0      NaN
# Closed Date                     362177.0   2381.0
# Agency                          364558.0      NaN
# Agency Name                     364558.0      NaN
# Complaint Type                  364558.0      NaN
# Descriptor                      358057.0   6501.0
# Location Type                   364425.0    133.0
# Incident Zip                    361560.0   2998.0
# Incident Address                312859.0  51699.0
# Street Name                     312859.0  51699.0
# Cross Street 1                  307370.0  57188.0
# Cross Street 2                  306753.0  57805.0
# Address Type                    361306.0   3252.0
# City                            361561.0   2997.0
# Facility Type                   362169.0   2389.0
# Status                          364558.0      NaN
# Due Date                        364555.0      3.0
# ...

# %%
df_3=df.dropna(subset=['Location','Resolution Action Updated Date'],inplace=True)

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                                    False     True
# Unique Key                      360448.0      NaN
# Created Date                    360448.0      NaN
# Closed Date                     360431.0     17.0
# Agency                          360448.0      NaN
# Agency Name                     360448.0      NaN
# Complaint Type                  360448.0      NaN
# Descriptor                      354025.0   6423.0
# Location Type                   360363.0     85.0
# Incident Zip                    360407.0     41.0
# Incident Address                308773.0  51675.0
# Street Name                     308773.0  51675.0
# Cross Street 1                  305628.0  54820.0
# Cross Street 2                  305619.0  54829.0
# Address Type                    360153.0    295.0
# City                            360407.0     41.0
# Facility Type                   360432.0     16.0
# Status                          360448.0      NaN
# Due Date                        360448.0      NaN
# ...

# %%
a=((df.isna().sum())/len(df))*100 #Percentage of remaining Null Values
a
# Out:
# Unique Key                         0.000000
# Created Date                       0.000000
# Closed Date                        0.004716
# Agency                             0.000000
# Agency Name                        0.000000
# Complaint Type                     0.000000
# Descriptor                         1.781949
# Location Type                      0.023582
# Incident Zip                       0.011375
# Incident Address                  14.336326
# Street Name                       14.336326
# Cross Street 1                    15.208851
# Cross Street 2                    15.211348
# Address Type                       0.081843
# City                               0.011375
# Facility Type                      0.004439
# Status                             0.000000
# Due Date                           0.000000
# Resolution Description             0.000000
# Resolution Action Updated Date     0.000000
# Community Board                    0.000000
# ...

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                                    False     True
# Unique Key                      360448.0      NaN
# Created Date                    360448.0      NaN
# Closed Date                     360431.0     17.0
# Agency                          360448.0      NaN
# Agency Name                     360448.0      NaN
# Complaint Type                  360448.0      NaN
# Descriptor                      354025.0   6423.0
# Location Type                   360363.0     85.0
# Incident Zip                    360407.0     41.0
# Incident Address                308773.0  51675.0
# Street Name                     308773.0  51675.0
# Cross Street 1                  305628.0  54820.0
# Cross Street 2                  305619.0  54829.0
# Address Type                    360153.0    295.0
# City                            360407.0     41.0
# Facility Type                   360432.0     16.0
# Status                          360448.0      NaN
# Due Date                        360448.0      NaN
# ...

# %%
#2.1Missing values haas been treated 
df_5=df.drop(['School Not Found','School Zip','School State','School City','School Address','School Phone Number','School Code','School Region','School Number','School Name','Park Facility Name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# ...

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                                    False     True
# Unique Key                      360448.0      NaN
# Created Date                    360448.0      NaN
# Closed Date                     360431.0     17.0
# Agency                          360448.0      NaN
# Agency Name                     360448.0      NaN
# Complaint Type                  360448.0      NaN
# Descriptor                      354025.0   6423.0
# Location Type                   360363.0     85.0
# Incident Zip                    360407.0     41.0
# Incident Address                308773.0  51675.0
# Street Name                     308773.0  51675.0
# Cross Street 1                  305628.0  54820.0
# Cross Street 2                  305619.0  54829.0
# Address Type                    360153.0    295.0
# City                            360407.0     41.0
# Facility Type                   360432.0     16.0
# Status                          360448.0      NaN
# Due Date                        360448.0      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 360448 entries, 0 to 364557
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      360448 non-null  int64
#  1   Created Date                    360448 non-null  object
#  2   Closed Date                     360431 non-null  object
#  3   Agency                          360448 non-null  object
#  4   Agency Name                     360448 non-null  object
#  5   Complaint Type                  360448 non-null  object
#  6   Descriptor                      354025 non-null  object
#  7   Location Type                   360363 non-null  object
#  8   Incident Zip                    360407 non-null  float64
#  9   Incident Address                308773 non-null  object
#  10  Street Name                     308773 non-null  object
#  11  Cross Street 1                  305628 non-null  object
# ...

# %%
#Analysis of the Date Column and Removing the entries with Incorrect timeline

# %%
df['Created Date']=pd.to_datetime(df['Created Date'])

# %%
df['Closed Date']=pd.to_datetime(df['Closed Date'])

# %%
df=df[df['Closed Date'].notna()]

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                                    False     True
# Unique Key                      360431.0      NaN
# Created Date                    360431.0      NaN
# Closed Date                     360431.0      NaN
# Agency                          360431.0      NaN
# Agency Name                     360431.0      NaN
# Complaint Type                  360431.0      NaN
# Descriptor                      354008.0   6423.0
# Location Type                   360346.0     85.0
# Incident Zip                    360390.0     41.0
# Incident Address                308761.0  51670.0
# Street Name                     308761.0  51670.0
# Cross Street 1                  305617.0  54814.0
# Cross Street 2                  305608.0  54823.0
# Address Type                    360136.0    295.0
# City                            360390.0     41.0
# Facility Type                   360423.0      8.0
# Status                          360431.0      NaN
# Due Date                        360431.0      NaN
# ...

# %%
#2.3Frequency plot for City wise complaint

df.loc[:,['Complaint Type','City']]
# Out:
#                  Complaint Type              City
# 0       Noise - Street/Sidewalk          NEW YORK
# 1              Blocked Driveway           ASTORIA
# 2              Blocked Driveway             BRONX
# 3               Illegal Parking             BRONX
# 4               Illegal Parking          ELMHURST
# ...                         ...               ...
# 364553          Illegal Parking         WOODHAVEN
# 364554          Noise - Vehicle             BRONX
# 364555  Noise - Street/Sidewalk          NEW YORK
# 364556         Blocked Driveway             BRONX
# 364557         Blocked Driveway  SOUTH OZONE PARK
#
# [360431 rows x 2 columns]

# %%
major=df.loc[:,'City']

# %%
major
# Out:
# 0                 NEW YORK
# 1                  ASTORIA
# 2                    BRONX
# 3                    BRONX
# 4                 ELMHURST
#                 ...
# 364553           WOODHAVEN
# 364554               BRONX
# 364555            NEW YORK
# 364556               BRONX
# 364557    SOUTH OZONE PARK
# Name: City, Length: 360431, dtype: object

# %%
major.unique()
# Out:
# array(['NEW YORK', 'ASTORIA', 'BRONX', 'ELMHURST', 'BROOKLYN',
#        'KEW GARDENS', 'JACKSON HEIGHTS', 'MIDDLE VILLAGE', 'REGO PARK',
#        'SAINT ALBANS', 'JAMAICA', 'SOUTH RICHMOND HILL', 'RIDGEWOOD',
#        'HOWARD BEACH', 'FOREST HILLS', 'STATEN ISLAND', 'OZONE PARK',
#        'RICHMOND HILL', 'WOODHAVEN', 'FLUSHING', 'CORONA',
#        'QUEENS VILLAGE', 'OAKLAND GARDENS', 'HOLLIS', 'MASPETH',
#        'EAST ELMHURST', 'SOUTH OZONE PARK', 'WOODSIDE', 'FRESH MEADOWS',
#        'LONG ISLAND CITY', 'ROCKAWAY PARK', 'SPRINGFIELD GARDENS',
#        'COLLEGE POINT', 'BAYSIDE', 'GLEN OAKS', 'FAR ROCKAWAY',
#        'BELLEROSE', 'LITTLE NECK', 'CAMBRIA HEIGHTS', 'ROSEDALE',
#        'SUNNYSIDE', 'WHITESTONE', 'ARVERNE', 'FLORAL PARK',
#        'NEW HYDE PARK', nan, 'CENTRAL PARK', 'BREEZY POINT', 'QUEENS',
#        'Astoria', 'Long Island City', 'Woodside', 'East Elmhurst',
#        'Howard Beach'], dtype=object)

# %%
major.nunique()
# Out:
# 53

# %%
top=major.value_counts()

# %%
top #Major Complaints are in blocked driveway
# Out:
# BROOKLYN               118624
# NEW YORK                76626
# BRONX                   49045
# STATEN ISLAND           15323
# JAMAICA                  8911
# ASTORIA                  7974
# FLUSHING                 7481
# RIDGEWOOD                6388
# CORONA                   5381
# WOODSIDE                 4353
# EAST ELMHURST            3557
# OZONE PARK               3446
# ELMHURST                 3437
# SOUTH RICHMOND HILL      3430
# MASPETH                  3116
# WOODHAVEN                3101
# LONG ISLAND CITY         3018
# SOUTH OZONE PARK         2668
# FRESH MEADOWS            2447
# RICHMOND HILL            2333
# MIDDLE VILLAGE           2290
# QUEENS VILLAGE           2251
# FOREST HILLS             2120
# JACKSON HEIGHTS          2105
# REGO PARK                1805
# BAYSIDE                  1548
# COLLEGE POINT            1544
# FAR ROCKAWAY             1396
# WHITESTONE               1367
# HOLLIS                   1231
# HOWARD BEACH             1143
# ...

# %%
top=top.head(10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
top.head(10).plot(kind='bar',title='City Wise Complaint and count')
# Out:
# <AxesSubplot:title={'center':'City Wise Complaint and count'}>

# %%
#2.4Scatter and hexbin plot in Brooklyn

# %%
plt.figure(figsize= (15,7))
plt.scatter(list(df['Location Type'].value_counts()[0:7].keys()),list(df['Location Type'].value_counts()[0:7]), color='r', s= 100)
plt.title('Complaint concentration acrross Brooklyn', size = 20)
plt.xlabel('Different Location acrross Brooklyn', size = 15)
plt.ylabel('Complaint concentration', size = 15)
plt.show()

# %%
#2.4.b Hexabin plot

# %%
df.plot(kind='hexbin', x='Longitude', y='Latitude', gridsize=40,
    colormap = 'jet',mincnt=1,title = 'Complaints concentration across Brooklyn\n', figsize=(10,6)).axis('equal')
# Out:
# (-74.28264833072548, -73.67300391470766, 40.47834893635428, 40.93356021717201)

# %%
#3.1 Bar Graph count vs Complaint types

# %%
df.loc[:,['Complaint Type','City']]
# Out:
#                  Complaint Type              City
# 0       Noise - Street/Sidewalk          NEW YORK
# 1              Blocked Driveway           ASTORIA
# 2              Blocked Driveway             BRONX
# 3               Illegal Parking             BRONX
# 4               Illegal Parking          ELMHURST
# ...                         ...               ...
# 364553          Illegal Parking         WOODHAVEN
# 364554          Noise - Vehicle             BRONX
# 364555  Noise - Street/Sidewalk          NEW YORK
# 364556         Blocked Driveway             BRONX
# 364557         Blocked Driveway  SOUTH OZONE PARK
#
# [360431 rows x 2 columns]

# %%
major=df.loc[:,"Complaint Type"]
major
# Out:
# 0         Noise - Street/Sidewalk
# 1                Blocked Driveway
# 2                Blocked Driveway
# 3                 Illegal Parking
# 4                 Illegal Parking
#                    ...
# 364553            Illegal Parking
# 364554            Noise - Vehicle
# 364555    Noise - Street/Sidewalk
# 364556           Blocked Driveway
# 364557           Blocked Driveway
# Name: Complaint Type, Length: 360431, dtype: object

# %%
major.unique()
# Out:
# array(['Noise - Street/Sidewalk', 'Blocked Driveway', 'Illegal Parking',
#        'Derelict Vehicle', 'Noise - Commercial',
#        'Noise - House of Worship', 'Posting Advertisement',
#        'Noise - Vehicle', 'Animal Abuse', 'Vending', 'Traffic',
#        'Drinking', 'Bike/Roller/Skate Chronic', 'Panhandling',
#        'Noise - Park', 'Homeless Encampment', 'Urinating in Public',
#        'Graffiti', 'Disorderly Youth', 'Illegal Fireworks', 'Squeegee'],
#       dtype=object)

# %%
major.nunique()
# Out:
# 21

# %%
top=major.value_counts()
top
# Out:
# Blocked Driveway             100487
# Illegal Parking               91084
# Noise - Street/Sidewalk       50815
# Noise - Commercial            43638
# Derelict Vehicle              21425
# Noise - Vehicle               19124
# Animal Abuse                  10503
# Traffic                        5166
# Homeless Encampment            4828
# Vending                        4162
# Noise - Park                   3994
# Drinking                       1400
# Noise - House of Worship       1061
# Posting Advertisement           678
# Urinating in Public             641
# Bike/Roller/Skate Chronic       463
# Panhandling                     320
# Disorderly Youth                314
# Illegal Fireworks               167
# Graffiti                        157
# Squeegee                          4
# Name: Complaint Type, dtype: int64

# %%
top.head(10)
# Out:
# Blocked Driveway           100487
# Illegal Parking             91084
# Noise - Street/Sidewalk     50815
# Noise - Commercial          43638
# Derelict Vehicle            21425
# Noise - Vehicle             19124
# Animal Abuse                10503
# Traffic                      5166
# Homeless Encampment          4828
# Vending                      4162
# Name: Complaint Type, dtype: int64

# %%
major.value_counts().plot(kind='bar',title='count vs. complaint types')
# Out:
# <AxesSubplot:title={'center':'count vs. complaint types'}>

# %%
#3.2 Top 10 types of Complaint
top.head(10)
# Out:
# Blocked Driveway           100487
# Illegal Parking             91084
# Noise - Street/Sidewalk     50815
# Noise - Commercial          43638
# Derelict Vehicle            21425
# Noise - Vehicle             19124
# Animal Abuse                10503
# Traffic                      5166
# Homeless Encampment          4828
# Vending                      4162
# Name: Complaint Type, dtype: int64

# %%
#3.3 Types of Complaints in separate data set
Sep_data_set = df[['Complaint Type','City']]
Sep_data_set
# Out:
#                  Complaint Type              City
# 0       Noise - Street/Sidewalk          NEW YORK
# 1              Blocked Driveway           ASTORIA
# 2              Blocked Driveway             BRONX
# 3               Illegal Parking             BRONX
# 4               Illegal Parking          ELMHURST
# ...                         ...               ...
# 364553          Illegal Parking         WOODHAVEN
# 364554          Noise - Vehicle             BRONX
# 364555  Noise - Street/Sidewalk          NEW YORK
# 364556         Blocked Driveway             BRONX
# 364557         Blocked Driveway  SOUTH OZONE PARK
#
# [360431 rows x 2 columns]

# %%
#4Visualize the major types of complaint in each city
df_2=df.loc[:,['Complaint Type','City']]

# %%
df_2
# Out:
#                  Complaint Type              City
# 0       Noise - Street/Sidewalk          NEW YORK
# 1              Blocked Driveway           ASTORIA
# 2              Blocked Driveway             BRONX
# 3               Illegal Parking             BRONX
# 4               Illegal Parking          ELMHURST
# ...                         ...               ...
# 364553          Illegal Parking         WOODHAVEN
# 364554          Noise - Vehicle             BRONX
# 364555  Noise - Street/Sidewalk          NEW YORK
# 364556         Blocked Driveway             BRONX
# 364557         Blocked Driveway  SOUTH OZONE PARK
#
# [360431 rows x 2 columns]

# %%
df_2.head(10)
# Out:
#             Complaint Type         City
# 0  Noise - Street/Sidewalk     NEW YORK
# 1         Blocked Driveway      ASTORIA
# 2         Blocked Driveway        BRONX
# 3          Illegal Parking        BRONX
# 4          Illegal Parking     ELMHURST
# 5          Illegal Parking     BROOKLYN
# 6          Illegal Parking     NEW YORK
# 7         Blocked Driveway        BRONX
# 8          Illegal Parking  KEW GARDENS
# 9         Blocked Driveway     BROOKLYN

# %%
df_2.value_counts().head(30).plot(kind='bar',title='Major types of complaints in each city')
# Out:
# <AxesSubplot:title={'center':'Major types of complaints in each city'}, xlabel='Complaint Type,City'>

# %%
#5 average response time Across varous type of compaint

# %%
df['Resolution Action Updated Date']=pd.to_datetime(df['Resolution Action Updated Date'])

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                                    False     True
# Unique Key                      360431.0      NaN
# Created Date                    360431.0      NaN
# Closed Date                     360431.0      NaN
# Agency                          360431.0      NaN
# Agency Name                     360431.0      NaN
# Complaint Type                  360431.0      NaN
# Descriptor                      354008.0   6423.0
# Location Type                   360346.0     85.0
# Incident Zip                    360390.0     41.0
# Incident Address                308761.0  51670.0
# Street Name                     308761.0  51670.0
# Cross Street 1                  305617.0  54814.0
# Cross Street 2                  305608.0  54823.0
# Address Type                    360136.0    295.0
# City                            360390.0     41.0
# Facility Type                   360423.0      8.0
# Status                          360431.0      NaN
# Due Date                        360431.0      NaN
# ...

# %%
Response_Time=df['Resolution Action Updated Date']-df['Created Date']

# %%
np.mean(Response_Time)
# Out:
# Timedelta('0 days 04:11:04.430476290')
